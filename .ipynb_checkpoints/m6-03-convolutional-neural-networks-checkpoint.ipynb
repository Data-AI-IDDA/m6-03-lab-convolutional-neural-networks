# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"
torch.manual_seed(42)

# %%
import torch

print(torch.cuda.is_available())        # True = GPU var, False = yok
print(torch.cuda.device_count())        # Kaç GPU var
print(torch.cuda.get_device_name(0))    # GPU'nun adı (varsa)
print(device)                           # cuda mi cpu mu kullanıyor
# Out:
# True
# 1
# NVIDIA GeForce RTX 3050 Laptop GPU
# cuda

# %% [markdown]
# ## Tasks
#
# ### Task 1 — Convolution Mechanics: Filters and Shapes
#
# Before training anything, build intuition for what a convolution actually does and how feature-map shapes evolve through a network.
#
# **Part A — Handcrafted filters.**
#
# 1. Load a single CIFAR-10 image and convert it to a `torch.Tensor` of shape `(1, 3, 32, 32)`.
# 2. Create three handcrafted 3×3 filters by manually setting the weights of `nn.Conv2d(3, 1, kernel_size=3, padding=1)`:
#    - **Vertical edge detector**: `[[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]]`
#    - **Horizontal edge detector**: transpose of the above
#    - **Blur**: `(1/9) * np.ones((3, 3))`
# 3. Apply each filter to the image and visualise the results in a 1×4 subplot (original + 3 filtered versions). Use `imshow(..., cmap="gray")` for the filtered outputs.
# 4. In a markdown cell, briefly describe what each filter highlights.
#
# **Part B — Shape tracking.**
#
# Build the following CNN block and verify shapes:
#
# ```python
# class TinyCNN(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
#         self.pool1 = nn.MaxPool2d(2)
#         self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
#         self.pool2 = nn.MaxPool2d(2)
# ```
#
# 1. Create a dummy input `x = torch.randn(8, 3, 32, 32)`.
# 2. Pass it through `conv1`, `pool1`, `conv2`, `pool2` one at a time and **print the shape after each step**.
# 3. Fill in this table:
#
# | Layer | Input shape | Output shape |
# |---|---|---|
# | conv1 | (8, 3, 32, 32) | … |
# | pool1 | … | … |
# | conv2 | … | … |
# | pool2 | … | … |

# %%
# ─── TASK 1 — Part A: Handcrafted Filters ───────────────────────────────────

import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# 1. Load an image from CIFAR-10
dataset = datasets.CIFAR10(root='./data', train=True, download=True,
                           transform=transforms.ToTensor())

image, label = dataset[0]               # shape: (3, 32, 32)
x = image.unsqueeze(0)                  # shape: (1, 3, 32, 32)  ← add batch dimension

# 2. Manually set filter weights
def make_conv(kernel_2d):
    """
    Takes a 2D kernel (3×3) and returns nn.Conv2d(3,1).
    The same kernel is applied to all 3 input channels, bias=0.
    """
    conv = nn.Conv2d(3, 1, kernel_size=3, padding=1, bias=False)
    with torch.no_grad():
        k = torch.tensor(kernel_2d, dtype=torch.float32)   # (3,3)
        # weight shape: (out_ch=1, in_ch=3, 3, 3)
        # We apply the exact same kernel to each of the 3 input channels
        conv.weight[0, 0] = k
        conv.weight[0, 1] = k
        conv.weight[0, 2] = k
    return conv

# Vertical edge detector
vertical_kernel = [[-1, 0, 1],
                   [-1, 0, 1],
                   [-1, 0, 1]]

# Horizontal edge detector (transpose of the vertical one)
horizontal_kernel = [[-1, -1, -1],
                     [ 0,  0,  0],
                     [ 1,  1,  1]]

# Blur (simple average of 9 pixels)
blur_kernel = (np.ones((3, 3)) / 9).tolist()

conv_v = make_conv(vertical_kernel)
conv_h = make_conv(horizontal_kernel)
conv_b = make_conv(blur_kernel)

# 3. Apply filters (no gradient calculation needed)
with torch.no_grad():
    out_v = conv_v(x)   # (1, 1, 32, 32)
    out_h = conv_h(x)
    out_b = conv_b(x)

# Convert tensor to numpy for visualization
def to_np(t):
    """(1,1,32,32) → (32,32) numpy array"""
    return t.squeeze().numpy()

original_np = image.permute(1, 2, 0).numpy()   # (32,32,3) — for imshow

# 4. 1×4 subplot
fig, axes = plt.subplots(1, 4, figsize=(14, 4))
fig.suptitle(f'CIFAR-10 Image — Class: {dataset.classes[label]}', fontsize=13)

axes[0].imshow(original_np)
axes[0].set_title('Original')
axes[0].axis('off')

axes[1].imshow(to_np(out_v), cmap='gray')
axes[1].set_title('Vertical Edge')
axes[1].axis('off')

axes[2].imshow(to_np(out_h), cmap='gray')
axes[2].set_title('Horizontal Edge')
axes[2].axis('off')

axes[3].imshow(to_np(out_b), cmap='gray')
axes[3].set_title('Blur')
axes[3].axis('off')

plt.tight_layout()
plt.savefig('task1_filters.png', dpi=120)
plt.show()
# Out:
# Files already downloaded and verified
# C:\Users\ASUS\iboo\IronHack\venv\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")

# %% [markdown]
# ## Filter descriptions
#
# **Vertical edge detector**
# Computes the left-right pixel difference. Vertical edges — the side contours
# of the body, the edges of the ears — appear as bright white lines.
# Flat uniform regions stay dark because the difference is close to zero.
#
# **Horizontal edge detector**
# Computes the top-bottom pixel difference. Horizontal edges — the line where
# the head meets the body, the bottom of the torso — appear bright.
# Vertical lines are invisible to this filter.
#
# **Blur**
# Replaces each pixel with the simple average of itself and its 8 neighbours.
# Sharp transitions are smoothed out and fine details are lost,
# producing an overall softer image.

# %%
# ─── TASK 1 — Part B: Shape Tracking ────────────────────────────────────────

class TinyCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3,  16, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(2)

model = TinyCNN()
x = torch.randn(8, 3, 32, 32)

print(f"Input  : {x.shape}")

x = model.conv1(x);  print(f"conv1  : {x.shape}")   # (8, 16, 32, 32)
x = model.pool1(x);  print(f"pool1  : {x.shape}")   # (8, 16, 16, 16)
x = model.conv2(x);  print(f"conv2  : {x.shape}")   # (8, 32, 16, 16)
x = model.pool2(x);  print(f"pool2  : {x.shape}")   # (8, 32,  8,  8)
# Out:
# Input  : torch.Size([8, 3, 32, 32])
# conv1  : torch.Size([8, 16, 32, 32])
# pool1  : torch.Size([8, 16, 16, 16])
# conv2  : torch.Size([8, 32, 16, 16])
# pool2  : torch.Size([8, 32, 8, 8])

# %% [markdown]
# ### Task 2 — Train a Small CNN on CIFAR-10
#
# Build a complete CNN classifier and train it.
#
# 1. Define a CNN with this architecture:
#    - Block 1: `Conv2d(3, 32, k=3, p=1)` → BatchNorm → ReLU → `Conv2d(32, 32, k=3, p=1)` → BatchNorm → ReLU → `MaxPool2d(2)`
#    - Block 2: `Conv2d(32, 64, k=3, p=1)` → BatchNorm → ReLU → `Conv2d(64, 64, k=3, p=1)` → BatchNorm → ReLU → `MaxPool2d(2)`
#    - Classifier: `Flatten` → `Linear(64*8*8, 256)` → ReLU → `Dropout(0.3)` → `Linear(256, 10)`
# 2. Compute the parameter count of your model and report it.
# 3. Train for **15 epochs** with `Adam(lr=1e-3)` and `CrossEntropyLoss`. Use batch size 128.
# 4. Track training and validation loss + accuracy per epoch. Plot the curves.
#
# **Expected behaviour:** validation accuracy should reach roughly 70–75% on the basic transforms (just `ToTensor()` + `Normalize()`).

# %%
# ─── TASK 2 — CNN on CIFAR-10 ────────────────────────────────────────────────

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

device = "cuda" if torch.cuda.is_available() else "cpu"
torch.manual_seed(42)

# ── 1. Data ──────────────────────────────────────────────────────────────────
tf = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
])

train_ds = datasets.CIFAR10('./data', train=True,  download=True,  transform=tf)
val_ds   = datasets.CIFAR10('./data', train=False, download=False, transform=tf)

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True,  num_workers=2)
val_loader   = DataLoader(val_ds,   batch_size=128, shuffle=False, num_workers=2)

# ── 2. Model ─────────────────────────────────────────────────────────────────
class CIFARCNN(nn.Module):
    def __init__(self):
        super().__init__()

        # Block 1 — 32×32 → 16×16
        self.block1 = nn.Sequential(
            nn.Conv2d(3,  32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )

        # Block 2 — 16×16 → 8×8
        self.block2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )

        # Classifier
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 8 * 8, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 10),
        )

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.classifier(x)
        return x

model = CIFARCNN().to(device)

# ── 3. Parameter Count ─────────────────────────────────────────────────────────
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params:,}")

# ── 4. Training ──────────────────────────────────────────────────────────────
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

history = {"train_loss": [], "val_loss": [],
           "train_acc":  [], "val_acc":  []}

def run_epoch(loader, train=True):
    model.train() if train else model.eval()
    total_loss, correct, total = 0.0, 0, 0

    ctx = torch.enable_grad() if train else torch.no_grad()
    with ctx:
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)

            if train:
                optimizer.zero_grad()

            outputs = model(images)
            loss    = criterion(outputs, labels)

            if train:
                loss.backward()
                optimizer.step()

            total_loss += loss.item() * images.size(0)
            correct    += (outputs.argmax(1) == labels).sum().item()
            total      += images.size(0)

    return total_loss / total, correct / total

for epoch in range(1, 16):
    tr_loss, tr_acc = run_epoch(train_loader, train=True)
    vl_loss, vl_acc = run_epoch(val_loader,   train=False)

    history["train_loss"].append(tr_loss)
    history["val_loss"].append(vl_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(vl_acc)

    print(f"Epoch {epoch:2d}/15 | "
          f"train loss: {tr_loss:.4f}  acc: {tr_acc:.3f} | "
          f"val loss: {vl_loss:.4f}  acc: {vl_acc:.3f}")

# ── 5. Plot ───────────────────────────────────────────────────────────────────
epochs = range(1, 16)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.plot(epochs, history["train_loss"], label="Train loss")
ax1.plot(epochs, history["val_loss"],   label="Val loss")
ax1.set_title("Loss")
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(epochs, history["train_acc"], label="Train acc")
ax2.plot(epochs, history["val_acc"],   label="Val acc")
ax2.set_title("Accuracy")
ax2.set_xlabel("Epoch")
ax2.legend()

plt.tight_layout()
plt.savefig("task2_curves.png", dpi=120)
plt.show()

print(f"\nBest validation accuracy: {max(history['val_acc']):.3f}")
# Out:
# Files already downloaded and verified
# Total parameters: 1,117,354
# Epoch  1/15 | train loss: 1.3216  acc: 0.520 | val loss: 1.0483  acc: 0.619
# Epoch  2/15 | train loss: 0.9311  acc: 0.673 | val loss: 0.8467  acc: 0.704
# Epoch  3/15 | train loss: 0.7885  acc: 0.721 | val loss: 0.7390  acc: 0.741
# Epoch  4/15 | train loss: 0.7058  acc: 0.751 | val loss: 0.8577  acc: 0.704
# Epoch  5/15 | train loss: 0.6390  acc: 0.774 | val loss: 0.7368  acc: 0.749
# Epoch  6/15 | train loss: 0.5797  acc: 0.796 | val loss: 0.7218  acc: 0.758
# Epoch  7/15 | train loss: 0.5274  acc: 0.813 | val loss: 0.6650  acc: 0.778
# Epoch  8/15 | train loss: 0.4862  acc: 0.829 | val loss: 0.6121  acc: 0.788
# Epoch  9/15 | train loss: 0.4460  acc: 0.841 | val loss: 0.6204  acc: 0.790
# Epoch 10/15 | train loss: 0.4031  acc: 0.854 | val loss: 0.7360  acc: 0.773
# Epoch 11/15 | train loss: 0.3761  acc: 0.866 | val loss: 0.6387  acc: 0.795
# ...

# %% [markdown]
# ### Task 3 — Data Augmentation
#
# Now show that augmentation matters.
#
# 1. Define a richer transform pipeline for the **training** loader:
#
# ```python
# train_tf = transforms.Compose([
#     transforms.RandomCrop(32, padding=4),
#     transforms.RandomHorizontalFlip(),
#     transforms.ColorJitter(brightness=0.1, contrast=0.1),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
# ])
# ```
#
# 2. Keep the **validation** transform plain (`ToTensor()` + `Normalize()`).
# 3. Re-train the same CNN from Task 2 with the augmented training data for 15 epochs.
# 4. Compare against the Task 2 baseline:
#
# | Run | Best val accuracy | Train/val gap |
# |---|---|---|
# | Task 2 (no augmentation) | … | … |
# | Task 3 (with augmentation) | … | … |
#
# 5. In a markdown cell, comment on what changed.

# %%
# ─── TASK 3 — Data Augmentation ──────────────────────────────────────────────

# ── 1. Augmented training transform ──────────────────────────────────────────
train_tf = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
])

# ── 2. Validation transform — simple, unchanged ──────────────────────────────
val_tf = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
])

train_ds_aug = datasets.CIFAR10('./data', train=True,  download=False, transform=train_tf)
val_ds_aug   = datasets.CIFAR10('./data', train=False, download=False, transform=val_tf)

train_loader_aug = DataLoader(train_ds_aug, batch_size=128, shuffle=True,  num_workers=2)
val_loader_aug   = DataLoader(val_ds_aug,   batch_size=128, shuffle=False, num_workers=2)

# ── 3. Reset the model — identical architecture to Task 2 ────────────────────
model_aug = CIFARCNN().to(device)
optimizer_aug = optim.Adam(model_aug.parameters(), lr=1e-3)

history_aug = {"train_loss": [], "val_loss": [],
               "train_acc":  [], "val_acc":  []}

def run_epoch_aug(loader, train=True):
    model_aug.train() if train else model_aug.eval()
    total_loss, correct, total = 0.0, 0, 0

    ctx = torch.enable_grad() if train else torch.no_grad()
    with ctx:
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)

            if train:
                optimizer_aug.zero_grad()

            outputs = model_aug(images)
            loss    = criterion(outputs, labels)

            if train:
                loss.backward()
                optimizer_aug.step()

            total_loss += loss.item() * images.size(0)
            correct    += (outputs.argmax(1) == labels).sum().item()
            total      += images.size(0)

    return total_loss / total, correct / total

for epoch in range(1, 16):
    tr_loss, tr_acc = run_epoch_aug(train_loader_aug, train=True)
    vl_loss, vl_acc = run_epoch_aug(val_loader_aug,   train=False)

    history_aug["train_loss"].append(tr_loss)
    history_aug["val_loss"].append(vl_loss)
    history_aug["train_acc"].append(tr_acc)
    history_aug["val_acc"].append(vl_acc)

    print(f"Epoch {epoch:2d}/15 | "
          f"train loss: {tr_loss:.4f}  acc: {tr_acc:.3f} | "
          f"val loss: {vl_loss:.4f}  acc: {vl_acc:.3f}")

# ── 4. Plot ───────────────────────────────────────────────────────────────────
epochs = range(1, 16)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.plot(epochs, history["train_loss"],     label="Train loss (no aug)", linestyle="--")
ax1.plot(epochs, history["val_loss"],       label="Val loss (no aug)",   linestyle="--")
ax1.plot(epochs, history_aug["train_loss"], label="Train loss (aug)")
ax1.plot(epochs, history_aug["val_loss"],   label="Val loss (aug)")
ax1.set_title("Loss — Task 2 vs Task 3")
ax1.set_xlabel("Epoch")
ax1.legend(fontsize=8)

ax2.plot(epochs, history["train_acc"],     label="Train acc (no aug)", linestyle="--")
ax2.plot(epochs, history["val_acc"],       label="Val acc (no aug)",   linestyle="--")
ax2.plot(epochs, history_aug["train_acc"], label="Train acc (aug)")
ax2.plot(epochs, history_aug["val_acc"],   label="Val acc (aug)")
ax2.set_title("Accuracy — Task 2 vs Task 3")
ax2.set_xlabel("Epoch")
ax2.legend(fontsize=8)

plt.tight_layout()
plt.savefig("task3_curves.png", dpi=120)
plt.show()

# ── 5. Comparison Table ───────────────────────────────────────────────────────
best_val_t2  = max(history["val_acc"])
best_val_t3  = max(history_aug["val_acc"])
gap_t2 = history["train_acc"][-1] - history["val_acc"][-1]
gap_t3 = history_aug["train_acc"][-1] - history_aug["val_acc"][-1]

print("\n── Comparison Table ──")
print(f"{'Run':<30} {'Best val acc':>14} {'Train/val gap':>14}")
print(f"{'Task 2 (no augmentation)':<30} {best_val_t2:>14.3f} {gap_t2:>14.3f}")
print(f"{'Task 3 (with augmentation)':<30} {best_val_t3:>14.3f} {gap_t3:>14.3f}")
# Out:
# Epoch  1/15 | train loss: 1.6004  acc: 0.416 | val loss: 1.1557  acc: 0.575
# Epoch  2/15 | train loss: 1.2073  acc: 0.563 | val loss: 1.0015  acc: 0.647
# Epoch  3/15 | train loss: 1.0448  acc: 0.626 | val loss: 1.0824  acc: 0.620
# Epoch  4/15 | train loss: 0.9636  acc: 0.658 | val loss: 0.8356  acc: 0.702
# Epoch  5/15 | train loss: 0.9039  acc: 0.680 | val loss: 0.8078  acc: 0.717
# Epoch  6/15 | train loss: 0.8616  acc: 0.696 | val loss: 0.8355  acc: 0.697
# Epoch  7/15 | train loss: 0.8203  acc: 0.712 | val loss: 0.7070  acc: 0.757
# Epoch  8/15 | train loss: 0.7993  acc: 0.720 | val loss: 0.8312  acc: 0.715
# Epoch  9/15 | train loss: 0.7692  acc: 0.731 | val loss: 0.6391  acc: 0.778
# Epoch 10/15 | train loss: 0.7433  acc: 0.740 | val loss: 0.6998  acc: 0.754
# Epoch 11/15 | train loss: 0.7269  acc: 0.749 | val loss: 0.6341  acc: 0.785
# Epoch 12/15 | train loss: 0.7075  acc: 0.753 | val loss: 0.6598  acc: 0.773
# ...

# %% [markdown]
# ## Task 3 — Data Augmentation: What Changed?
#
# ### Results summary
#
# | Run | Best val acc | Train/val gap |
# |---|---|---|
# | Task 2 (no augmentation) | 0.798 | 0.110 |
# | Task 3 (with augmentation) | 0.794 | -0.016 |
#
# ### What changed?
#
# **Overfitting dropped significantly.**
# In Task 2, the train/val gap reached 0.110 by the final epoch — the model
# was memorising the training data. With augmentation, this gap collapsed
# to near zero (-0.016), meaning the model generalised far more consistently.
#
# **Validation accuracy stayed roughly the same.**
# The best val accuracy barely changed (0.798 → 0.794). This is expected
# with only 15 epochs — augmentation slows down learning because the model
# sees a different version of each image every epoch. Given more epochs
# (~25–30), the augmented model would likely surpass the baseline.
#
# **Training accuracy dropped.**
# Train acc fell from 0.905 to 0.771. This is not a failure — it means
# the model is no longer memorising fixed images. Harder training examples
# force it to learn more robust features.
#
# ### Conclusion
#
# Data augmentation did not improve peak accuracy in this short run,
# but it achieved its primary goal: reducing the gap between training
# and validation performance. In practice, a smaller train/val gap means
# the model is more reliable on unseen data — which matters far more
# than a marginally higher training score.
