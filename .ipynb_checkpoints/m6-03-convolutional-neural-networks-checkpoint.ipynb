# %% [markdown]
# ## Convolution Mechanics (Part A)
#
# In this section, we apply handcrafted convolution filters to a single CIFAR-10 image to understand how convolution extracts features such as edges and textures.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"
torch.manual_seed(42)

# %%
from torchvision import datasets, transforms
import torch
import matplotlib.pyplot as plt

tf = transforms.ToTensor()

dataset = datasets.CIFAR10(root="./data", train=True, download=True, transform=tf)

image, label = dataset[0]

# shape: (3, 32, 32) → (1, 3, 32, 32)
image = image.unsqueeze(0)

print(image.shape)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 170M/170M [01:27<00:00, 1.94MB/s]
# torch.Size([1, 3, 32, 32])
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")

# %%
import torch.nn as nn
import numpy as np

# Conv layer (3 input channel → 1 output)
conv = nn.Conv2d(3, 1, kernel_size=3, padding=1, bias=False)

# Filters
vertical = np.array([[-1, 0, 1],
                     [-1, 0, 1],
                     [-1, 0, 1]])

horizontal = vertical.T
blur = (1/9) * np.ones((3,3))

# %%
def apply_filter(filter_kernel):
    # weight shape: (out_channels, in_channels, k, k)
    weight = np.stack([filter_kernel]*3)  # 3 channels üçün
    weight = torch.tensor(weight, dtype=torch.float32).unsqueeze(0)

    conv.weight.data = weight

    with torch.no_grad():
        output = conv(image)

    return output.squeeze().numpy()

# %%
vertical_out = apply_filter(vertical)
horizontal_out = apply_filter(horizontal)
blur_out = apply_filter(blur)

# %%
fig, axes = plt.subplots(1, 4, figsize=(12,4))

# original image (channel-last format)
axes[0].imshow(image.squeeze().permute(1,2,0))
axes[0].set_title("Original")
axes[0].axis("off")

axes[1].imshow(vertical_out, cmap="gray")
axes[1].set_title("Vertical Edge")
axes[1].axis("off")

axes[2].imshow(horizontal_out, cmap="gray")
axes[2].set_title("Horizontal Edge")
axes[2].axis("off")

axes[3].imshow(blur_out, cmap="gray")
axes[3].set_title("Blur")
axes[3].axis("off")

plt.show()

# %% [markdown]
# The vertical edge filter highlights vertical structures in the image by detecting changes in intensity across columns. This makes vertical boundaries and contours more visible.
#
# The horizontal edge filter emphasizes horizontal patterns by detecting changes across rows, highlighting features such as edges and object boundaries in the horizontal direction.
#
# The blur filter smooths the image by averaging neighboring pixel values, which reduces noise and removes fine details, resulting in a softer appearance.
#
# These results demonstrate how convolutional filters extract specific patterns from images, forming the basis of feature learning in convolutional neural networks.

# %% [markdown]
# ## Convolution Mechanics (Part B)
#
# In this section, we track how the shape of the feature maps changes as the input passes through convolutional and pooling layers.

# %%
import torch.nn as nn

class TinyCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(2)

# %%
x = torch.randn(8, 3, 32, 32)
print("Input:", x.shape)
# Out:
# Input: torch.Size([8, 3, 32, 32])

# %%
model = TinyCNN()

x1 = model.conv1(x)
print("After conv1:", x1.shape)

x2 = model.pool1(x1)
print("After pool1:", x2.shape)

x3 = model.conv2(x2)
print("After conv2:", x3.shape)

x4 = model.pool2(x3)
print("After pool2:", x4.shape)
# Out:
# After conv1: torch.Size([8, 16, 32, 32])
# After pool1: torch.Size([8, 16, 16, 16])
# After conv2: torch.Size([8, 32, 16, 16])
# After pool2: torch.Size([8, 32, 8, 8])

# %% [markdown]
# | Layer  | Input shape        | Output shape       |
# |--------|-------------------|--------------------|
# | conv1  | (8, 3, 32, 32)    | (8, 16, 32, 32)    |
# | pool1  | (8, 16, 32, 32)   | (8, 16, 16, 16)    |
# | conv2  | (8, 16, 16, 16)   | (8, 32, 16, 16)    |
# | pool2  | (8, 32, 16, 16)   | (8, 32, 8, 8)      |

# %% [markdown]
# # Train a Small CNN on CIFAR-10
#
# In this task, I build and train a small convolutional neural network for CIFAR-10 image classification.
#
# The model uses convolutional blocks to extract image features, followed by a fully connected classifier to predict one of the 10 CIFAR-10 classes.

# %% [markdown]
# ## Loading CIFAR-10 Data
#
# For the baseline model, I use basic preprocessing:
#
# - Convert images to tensors
# - Normalize RGB channels to roughly the range [-1, 1]
#
# The training set is shuffled, while the validation set is kept fixed.

# %%
# Basic transform for Task 2
basic_tf = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

train_set = datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=basic_tf
)

val_set = datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=basic_tf
)

train_loader = DataLoader(train_set, batch_size=128, shuffle=True)
val_loader = DataLoader(val_set, batch_size=128, shuffle=False)

print("Train size:", len(train_set))
print("Validation size:", len(val_set))
# Out:
# Train size: 50000
# Validation size: 10000

# %% [markdown]
# ## CNN Architecture
#
# The CNN has two convolutional blocks.
#
# Each block extracts spatial features from the image while MaxPool reduces the image size.
#
# After two pooling layers, the feature map becomes:
#
# `64 × 8 × 8`
#
# This is then flattened and passed into a fully connected classifier.

# %%
class CIFAR10CNN(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            
            nn.MaxPool2d(2),   # 32x32 -> 16x16
            
            # Block 2
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            
            nn.MaxPool2d(2)    # 16x16 -> 8x8
        )
        
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 8 * 8, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 10)
        )
        
    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Parameter Count
#
# Before training, I calculate the number of trainable parameters in the model.
#
# This helps understand the model size and complexity.

# %%
model = CIFAR10CNN().to(device)

print(model)

num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Trainable parameters:", num_params)
# Out:
# CIFAR10CNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (12): ReLU()
# ...

# %% [markdown]
# ## Training Function
#
# This function trains the CNN and tracks:
#
# - Training loss
# - Validation loss
# - Training accuracy
# - Validation accuracy
#
# These metrics help evaluate learning behavior across epochs.

# %%
def train_cnn(model, train_loader, val_loader, epochs=15, lr=1e-3):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []
    
    for epoch in range(epochs):
        # TRAIN
        model.train()
        train_loss = 0
        correct_train = 0
        total_train = 0
        
        for X, y in train_loader:
            X, y = X.to(device), y.to(device)
            
            optimizer.zero_grad()
            outputs = model(X)
            loss = criterion(outputs, y)
            
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            
            _, preds = torch.max(outputs, 1)
            correct_train += (preds == y).sum().item()
            total_train += y.size(0)
        
        train_loss /= len(train_loader)
        train_acc = correct_train / total_train
        
        # VALIDATION
        model.eval()
        val_loss = 0
        correct_val = 0
        total_val = 0
        
        with torch.no_grad():
            for X, y in val_loader:
                X, y = X.to(device), y.to(device)
                
                outputs = model(X)
                loss = criterion(outputs, y)
                
                val_loss += loss.item()
                
                _, preds = torch.max(outputs, 1)
                correct_val += (preds == y).sum().item()
                total_val += y.size(0)
        
        val_loss /= len(val_loader)
        val_acc = correct_val / total_val
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        
        print(
            f"Epoch [{epoch+1}/{epochs}] "
            f"Train Loss: {train_loss:.4f} "
            f"Train Acc: {train_acc:.4f} "
            f"Val Loss: {val_loss:.4f} "
            f"Val Acc: {val_acc:.4f}"
        )
    
    return train_losses, val_losses, train_accs, val_accs

# %% [markdown]
# ## Training the Baseline CNN
#
# The baseline CNN is trained for 15 epochs using Adam with learning rate `1e-3`.
#
# This gives us a reference result before applying data augmentation in Task 3.

# %%
baseline_model = CIFAR10CNN().to(device)

baseline_train_losses, baseline_val_losses, baseline_train_accs, baseline_val_accs = train_cnn(
    baseline_model,
    train_loader,
    val_loader,
    epochs=15,
    lr=1e-3
)
# Out:
# Epoch [1/15] Train Loss: 1.3577 Train Acc: 0.5061 Val Loss: 1.0113 Val Acc: 0.6505
# Epoch [2/15] Train Loss: 0.9440 Train Acc: 0.6652 Val Loss: 0.8594 Val Acc: 0.6961
# Epoch [3/15] Train Loss: 0.8159 Train Acc: 0.7128 Val Loss: 0.7377 Val Acc: 0.7418
# Epoch [4/15] Train Loss: 0.7212 Train Acc: 0.7459 Val Loss: 0.7799 Val Acc: 0.7277
# Epoch [5/15] Train Loss: 0.6539 Train Acc: 0.7698 Val Loss: 0.7419 Val Acc: 0.7463
# Epoch [6/15] Train Loss: 0.5938 Train Acc: 0.7904 Val Loss: 0.6959 Val Acc: 0.7654
# Epoch [7/15] Train Loss: 0.5492 Train Acc: 0.8073 Val Loss: 0.6965 Val Acc: 0.7700
# Epoch [8/15] Train Loss: 0.5061 Train Acc: 0.8215 Val Loss: 0.6555 Val Acc: 0.7720
# Epoch [9/15] Train Loss: 0.4668 Train Acc: 0.8322 Val Loss: 0.6877 Val Acc: 0.7703
# Epoch [10/15] Train Loss: 0.4371 Train Acc: 0.8447 Val Loss: 0.6800 Val Acc: 0.7750
# Epoch [11/15] Train Loss: 0.4021 Train Acc: 0.8562 Val Loss: 0.6168 Val Acc: 0.7975
# ...

# %% [markdown]
# ## Training Curves
#
# I plot loss and accuracy curves to see how the CNN learns over time and whether it generalizes well to the validation set.

# %%
epochs_range = range(1, 16)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(epochs_range, baseline_train_losses, label="Train Loss")
axes[0].plot(epochs_range, baseline_val_losses, label="Validation Loss")
axes[0].set_title("Baseline CNN Loss")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()

axes[1].plot(epochs_range, baseline_train_accs, label="Train Accuracy")
axes[1].plot(epochs_range, baseline_val_accs, label="Validation Accuracy")
axes[1].set_title("Baseline CNN Accuracy")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].legend()

plt.show()

# %%
baseline_best_val_acc = max(baseline_val_accs)
baseline_best_epoch = baseline_val_accs.index(baseline_best_val_acc) + 1

baseline_final_train_acc = baseline_train_accs[-1]
baseline_train_val_gap = baseline_final_train_acc - baseline_best_val_acc

print(f"Best Validation Accuracy: {baseline_best_val_acc:.4f}")
print(f"Best Epoch: {baseline_best_epoch}")
print(f"Train/Val Gap: {baseline_train_val_gap:.4f}")
# Out:
# Best Validation Accuracy: 0.8017
# Best Epoch: 12
# Train/Val Gap: 0.0914

# %% [markdown]
# ## Baseline CNN Interpretation
#
# The baseline CNN successfully learned meaningful features from the CIFAR-10 dataset. The training loss decreased steadily from **1.3577** to **0.2925**, while training accuracy improved from **50.61%** to **89.31%**, indicating that the model fit the training data effectively.
#
# Validation accuracy improved significantly during the early epochs and reached its best value of **80.17% at epoch 12**, which is above the expected 70–75% range for this architecture. This shows that the model learned strong and useful representations for the classification task.
#
# After epoch 12, validation performance slightly declined while training accuracy continued to increase. This divergence indicates that the model began to overfit the training data.
#
# The final **train/validation gap is 0.0914**, confirming noticeable overfitting. Therefore, the best-performing model corresponds to **epoch 12**, rather than the final epoch.
#
# Overall, the model achieved strong performance, but there is clear room for improvement in generalization. This baseline result will be used for comparison with the augmented model in the next task.

# %% [markdown]
# # Data Augmentation
#
# In this task, I retrain the same CNN architecture using data augmentation.
#
# Data augmentation creates slightly modified versions of training images, such as cropped, flipped, or color-adjusted images. This helps the model become more robust and reduces overfitting.
#
# The validation transform stays plain so evaluation remains fair and consistent.

# %%
# Augmented transform for training
train_tf = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
])

# Plain transform for validation
val_tf = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3),
])

# %%
aug_train_set = datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=train_tf
)

aug_val_set = datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=val_tf
)

aug_train_loader = DataLoader(
    aug_train_set,
    batch_size=128,
    shuffle=True
)

aug_val_loader = DataLoader(
    aug_val_set,
    batch_size=128,
    shuffle=False
)

print("Augmented train size:", len(aug_train_set))
print("Validation size:", len(aug_val_set))
# Out:
# Augmented train size: 50000
# Validation size: 10000

# %% [markdown]
# ## Training with Augmentation
#
# I train a fresh copy of the same CNN architecture from Task 2.
#
# The only major difference is that the training images are now randomly transformed during training.

# %%
aug_model = CIFAR10CNN().to(device)

aug_train_losses, aug_val_losses, aug_train_accs, aug_val_accs = train_cnn(
    aug_model,
    aug_train_loader,
    aug_val_loader,
    epochs=15,
    lr=1e-3
)
# Out:
# Epoch [1/15] Train Loss: 1.5741 Train Acc: 0.4228 Val Loss: 1.1851 Val Acc: 0.5645
# Epoch [2/15] Train Loss: 1.2146 Train Acc: 0.5637 Val Loss: 1.0106 Val Acc: 0.6327
# Epoch [3/15] Train Loss: 1.0609 Train Acc: 0.6199 Val Loss: 0.8457 Val Acc: 0.7009
# Epoch [4/15] Train Loss: 0.9652 Train Acc: 0.6588 Val Loss: 0.8156 Val Acc: 0.7093
# Epoch [5/15] Train Loss: 0.9038 Train Acc: 0.6817 Val Loss: 0.7966 Val Acc: 0.7185
# Epoch [6/15] Train Loss: 0.8494 Train Acc: 0.7011 Val Loss: 0.7310 Val Acc: 0.7444
# Epoch [7/15] Train Loss: 0.8204 Train Acc: 0.7129 Val Loss: 0.7766 Val Acc: 0.7293
# Epoch [8/15] Train Loss: 0.7891 Train Acc: 0.7244 Val Loss: 0.7754 Val Acc: 0.7318
# Epoch [9/15] Train Loss: 0.7626 Train Acc: 0.7338 Val Loss: 0.6334 Val Acc: 0.7825
# Epoch [10/15] Train Loss: 0.7406 Train Acc: 0.7405 Val Loss: 0.6651 Val Acc: 0.7741
# Epoch [11/15] Train Loss: 0.7222 Train Acc: 0.7503 Val Loss: 0.5997 Val Acc: 0.7906
# ...

# %% [markdown]
# ## Augmented Model Curves
#
# I plot the loss and accuracy curves for the augmented model to observe how training behavior changed compared to the baseline.

# %%
epochs_range = range(1, 16)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(epochs_range, aug_train_losses, label="Train Loss")
axes[0].plot(epochs_range, aug_val_losses, label="Validation Loss")
axes[0].set_title("Augmented CNN Loss")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()

axes[1].plot(epochs_range, aug_train_accs, label="Train Accuracy")
axes[1].plot(epochs_range, aug_val_accs, label="Validation Accuracy")
axes[1].set_title("Augmented CNN Accuracy")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].legend()

plt.show()

# %%
aug_best_val_acc = max(aug_val_accs)
aug_best_epoch = aug_val_accs.index(aug_best_val_acc) + 1

aug_final_train_acc = aug_train_accs[-1]
aug_train_val_gap = aug_final_train_acc - aug_best_val_acc

print(f"Best Augmented Validation Accuracy: {aug_best_val_acc:.4f}")
print(f"Best Epoch: {aug_best_epoch}")
print(f"Train/Val Gap: {aug_train_val_gap:.4f}")
# Out:
# Best Augmented Validation Accuracy: 0.8060
# Best Epoch: 15
# Train/Val Gap: -0.0316

# %% [markdown]
# ## Augmented CNN Interpretation
#
# The augmented model learned more gradually compared to the baseline, as expected, because the training data is more challenging due to random transformations.
#
# The best validation accuracy reached **80.60% at epoch 15**, slightly outperforming the baseline model. Although the improvement is modest, it shows that augmentation can enhance performance when the model is trained sufficiently.
#
# The most significant change is in the train/validation gap, which decreased from **0.0914** in the baseline model to **-0.0316**. This indicates that the model no longer overfits the training data and instead generalizes better to unseen data.
#
# The negative gap occurs because augmented training images are more difficult, while validation images remain clean, leading to slightly higher validation performance.
#
# Overall, data augmentation both **reduces overfitting** and **improves generalization**, while also achieving a small gain in validation accuracy.

# %%
import pandas as pd

comparison_df = pd.DataFrame({
    "Run": ["Task 2 (no augmentation)", "Task 3 (with augmentation)"],
    "Best val accuracy": [baseline_best_val_acc, aug_best_val_acc],
    "Train/val gap": [baseline_train_val_gap, aug_train_val_gap]
})

comparison_df
# Out:
#                           Run  Best val accuracy  Train/val gap
# 0    Task 2 (no augmentation)             0.8017        0.09138
# 1  Task 3 (with augmentation)             0.8060       -0.03156

# %% [markdown]
# ## Data Augmentation Comparison
#
# The baseline model achieved a best validation accuracy of **80.17%**, while the augmented model improved this to **80.60%**.
#
# Although the increase in accuracy is modest, the key improvement is in generalization. The baseline model shows clear overfitting, with a train/validation gap of **0.0914**. In contrast, the augmented model reduces this gap to **-0.0316**, indicating significantly better generalization.
#
# This happens because data augmentation makes the training data more challenging through random transformations, forcing the model to learn more robust and generalizable features rather than memorizing the training data.
#
# Overall, data augmentation both **improves validation accuracy** and **reduces overfitting**, making the model more reliable for real-world scenarios.
